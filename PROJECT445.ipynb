# %%
import pandas as pd

# %%
df = pd.read_excel('japan_data.xlsx')

# %%
df.head()
# Out:
#    ID  Residence  Sex  Age  Age_Group  Job_Group  Health_Worker_Self  \
# 0   1          2    1   65          1          4                   2
# 1   2          7    1   55          2          1                   2
# 2   3          3    1   60          2          1                   2
# 3   4          5    1   57          2          1                   2
# 4   5          7    1   53          2          1                   2
#
#    Health_Worker_Family  Married  Income  ...  Interaction_Online  \
# 0                     2        2     2.0  ...                   2
# 1                     2        2     4.0  ...                   3
# 2                     2        2     3.0  ...                   1
# 3                     1        2     4.0  ...                   1
# 4                     1        2     4.0  ...                   5
#
#    Preventive_Behaviors  Optimism  Deterioration_Economy  \
# 0                     7         4                      4
# ...

# %%
df.isnull().sum()
# Out:
# ID                           0
# Residence                    0
# Sex                          0
# Age                          0
# Age_Group                    0
# Job_Group                    0
# Health_Worker_Self           0
# Health_Worker_Family         0
# Married                      0
# Income                    1707
# Current_Physical             0
# Past_Physical                0
# Current_Mental               0
# Past_Mental                  0
# K6                           0
# PHQ9                         0
# UCLA_LS3                     0
# LSNS6                        0
# Exercise                     0
# Healthy_Diet                 0
# Healthy_Sleep                0
# Activity                     0
# Interaction_Offline          0
# Interaction_Online           0
# Preventive_Behaviors         0
# Optimism                     0
# Deterioration_Economy        0
# Deterioration_Interact       0
# Frustration                  0
# Covid_Anxiety                0
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (9626, 33)

# %%
df.columns
# Out:
# Index(['ID', 'Residence', 'Sex', 'Age', 'Age_Group', 'Job_Group',
#        'Health_Worker_Self', 'Health_Worker_Family', 'Married', 'Income',
#        'Current_Physical', 'Past_Physical', 'Current_Mental', 'Past_Mental',
#        'K6', 'PHQ9', 'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet',
#        'Healthy_Sleep', 'Activity', 'Interaction_Offline',
#        'Interaction_Online', 'Preventive_Behaviors', 'Optimism',
#        'Deterioration_Economy', 'Deterioration_Interact', 'Frustration',
#        'Covid_Anxiety', 'Covid_Sleepless', 'Difficulty_Living',
#        'Difficulty_Work'],
#       dtype='object')

# %%
def print_unique_col_values(df):
       for column in df:
            #if df[column].dtypes=='object':
            print(f'{column}: {df[column].unique()}')

# %%
#print(df['Sex'].unique())
print_unique_col_values(df)
# Out:
# ID: [    1     2     3 ... 11324 11326 11327]
# Residence: [2 7 3 5 4 6 1]
# Sex: [1 2]
# Age: [65 55 60 57 53 56 59 66 51 48 52 45 62 49 68 58 46 42 67 47 61 54 50 64
#  63 72 71 79 70 76 32 41 40 74 43 44 37 78 86 69 31 75 80 39 82 77 73 81
#  85 35 83 36 89 38 30 33 34 84 20 28 29 25 26 27 24 23 22 21 87 19 18 88]
# Age_Group: [1 2 3 4]
# Job_Group: [4 1 2 5 3]
# Health_Worker_Self: [2 1]
# Health_Worker_Family: [2 1]
# Married: [2 1]
# Income: [ 2.  4.  3.  7. 10.  8.  5.  1.  9.  6.]
# Current_Physical: [2 1]
# Past_Physical: [2 1]
# Current_Mental: [2 1]
# Past_Mental: [2 1]
# K6: [ 6 10  8  1  3  0  2  5 12  4  9 18 14 24 13  7 11 20 19 17 16 15 23 21
#  22]
# PHQ9: [10  6  5  8  0  4  9 12  3  1  2 14 11  7 21 24 18 17 27 13 16 15 25 23
#  19 20 26 22]
# UCLA_LS3: [27 25 30 26 14 23 33 11 28 32 29 21 17 16 19 35 24 15 18 20 22 13 12 37
#  34 31 40 36 38 10 39]
# LSNS6: [ 2 15  6  9  3 12  5 19  1  4 13 10 16 18 14  0  8  7 11 17 21 23 20 22
#  30 24 27 25 26 28 29]
# ...

# %%
df.drop(columns = 'ID', inplace=True)

# %%
print(df['Residence'].unique())
# Out:
# [2 7 3 5 4 6 1]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() # instantiate label encoder in an object le
df['Sex'] =le.fit_transform(df['Sex']) 
df['Past_Physical'] =le.fit_transform(df['Past_Physical']) 
df['Health_Worker_Self'] =le.fit_transform(df['Health_Worker_Self']) 
df['Health_Worker_Family'] =le.fit_transform(df['Health_Worker_Family']) 
df['Current_Mental'] =le.fit_transform(df['Current_Mental']) 
df['Current_Physical'] =le.fit_transform(df['Current_Physical']) 
df['Married'] =le.fit_transform(df['Married']) 
df['Past_Mental'] =le.fit_transform(df['Past_Mental'])

# %%
df = pd.get_dummies(data=df, columns=['Residence'])

# %%
df.columns
# Out:
# Index(['Sex', 'Age', 'Age_Group', 'Job_Group', 'Health_Worker_Self',
#        'Health_Worker_Family', 'Married', 'Income', 'Current_Physical',
#        'Past_Physical', 'Current_Mental', 'Past_Mental', 'K6', 'PHQ9',
#        'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet', 'Healthy_Sleep',
#        'Activity', 'Interaction_Offline', 'Interaction_Online',
#        'Preventive_Behaviors', 'Optimism', 'Deterioration_Economy',
#        'Deterioration_Interact', 'Frustration', 'Covid_Anxiety',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6', 'Residence_7'],
#       dtype='object')

# %%
df.drop(columns='Residence_7',inplace=True)

# %%
df.columns
# Out:
# Index(['Sex', 'Age', 'Age_Group', 'Job_Group', 'Health_Worker_Self',
#        'Health_Worker_Family', 'Married', 'Income', 'Current_Physical',
#        'Past_Physical', 'Current_Mental', 'Past_Mental', 'K6', 'PHQ9',
#        'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet', 'Healthy_Sleep',
#        'Activity', 'Interaction_Offline', 'Interaction_Online',
#        'Preventive_Behaviors', 'Optimism', 'Deterioration_Economy',
#        'Deterioration_Interact', 'Frustration', 'Covid_Anxiety',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
var_thresh = VarianceThreshold()

# %%
var_thresh.fit(df)
# Out:
# VarianceThreshold()

# %%
var_thresh.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
print(df.columns)
# Out:
# Index(['Sex', 'Age', 'Age_Group', 'Job_Group', 'Health_Worker_Self',
#        'Health_Worker_Family', 'Married', 'Income', 'Current_Physical',
#        'Past_Physical', 'Current_Mental', 'Past_Mental', 'K6', 'PHQ9',
#        'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet', 'Healthy_Sleep',
#        'Activity', 'Interaction_Offline', 'Interaction_Online',
#        'Preventive_Behaviors', 'Optimism', 'Deterioration_Economy',
#        'Deterioration_Interact', 'Frustration', 'Covid_Anxiety',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
print(df.columns[var_thresh.get_support()])
# Out:
# Index(['Sex', 'Age', 'Age_Group', 'Job_Group', 'Health_Worker_Self',
#        'Health_Worker_Family', 'Married', 'Income', 'Current_Physical',
#        'Past_Physical', 'Current_Mental', 'Past_Mental', 'K6', 'PHQ9',
#        'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet', 'Healthy_Sleep',
#        'Activity', 'Interaction_Offline', 'Interaction_Online',
#        'Preventive_Behaviors', 'Optimism', 'Deterioration_Economy',
#        'Deterioration_Interact', 'Frustration', 'Covid_Anxiety',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
print(len(df.columns[var_thresh.get_support()]))
# Out:
# 37

# %%
y = df['Covid_Anxiety']

# %%
X = df.drop(columns = 'Covid_Anxiety')

# %%
X.head()
# Out:
#    Sex  Age  Age_Group  Job_Group  Health_Worker_Self  Health_Worker_Family  \
# 0    0   65          1          4                   1                     1
# 1    0   55          2          1                   1                     1
# 2    0   60          2          1                   1                     1
# 3    0   57          2          1                   1                     0
# 4    0   53          2          1                   1                     0
#
#    Married  Income  Current_Physical  Past_Physical  ...  Frustration  \
# 0        1     2.0                 1              1  ...            5
# 1        1     4.0                 1              1  ...            4
# 2        1     3.0                 1              1  ...            4
# 3        1     4.0                 1              1  ...            1
# 4        1     4.0                 1              1  ...            5
#
#    Covid_Sleepless  Difficulty_Living  Difficulty_Work  Residence_1  \
# ...

# %%
y.head()
# Out:
# 0    5
# 1    4
# 2    5
# 3    1
# 4    5
# Name: Covid_Anxiety, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1, stratify = y)

# %%
from sklearn.preprocessing import MinMaxScaler
cols_to_scale = ['Age','Age_Group','Job_Group','Income','K6','PHQ9','UCLA_LS3','LSNS6','Exercise','Healthy_Diet','Healthy_Sleep','Activity','Interaction_Offline','Interaction_Offline','Interaction_Online','Preventive_Behaviors','Optimism','Deterioration_Economy','Deterioration_Interact','Frustration','Covid_Sleepless','Difficulty_Living','Difficulty_Work']
scaler = MinMaxScaler()
scaler.fit(X_train[cols_to_scale])
X_train[cols_to_scale] = scaler.transform(X_train[cols_to_scale])
X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
X_train.head()
# Out:
#       Sex       Age  Age_Group  Job_Group  Health_Worker_Self  \
# 3200    0  0.211268   0.666667        0.0                   1
# 8397    0  0.154930   0.666667        0.0                   0
# 4000    0  0.492958   0.333333        0.0                   1
# 6928    1  0.183099   0.666667        0.0                   1
# 8510    0  0.323944   0.333333        0.0                   1
#
#       Health_Worker_Family  Married    Income  Current_Physical  \
# 3200                     1        1  0.333333                 1
# 8397                     0        0  0.000000                 1
# 4000                     1        1  0.222222                 1
# 6928                     1        0  0.222222                 1
# 8510                     1        1  0.222222                 1
#
#       Past_Physical  ...  Frustration  Covid_Sleepless  Difficulty_Living  \
# 3200              1  ...     0.166667         0.166667           0.166667
# ...

# %%
corr = X_train.corr()#pearson correlation

# %%
corr
# Out:
#                              Sex       Age  Age_Group  Job_Group  \
# Sex                     1.000000 -0.312677   0.282284  -0.021246
# Age                    -0.312677  1.000000  -0.909164   0.210068
# Age_Group               0.282284 -0.909164   1.000000  -0.214646
# Job_Group              -0.021246  0.210068  -0.214646   1.000000
# Health_Worker_Self     -0.083647  0.100754  -0.095128   0.070053
# Health_Worker_Family   -0.011849  0.065283  -0.064463   0.006949
# Married                -0.052727  0.309281  -0.267555  -0.066219
# Income                  0.035679 -0.046186   0.055031  -0.015520
# Current_Physical        0.099232 -0.146756   0.134424  -0.069998
# Past_Physical           0.099818 -0.200593   0.182853  -0.106442
# Current_Mental         -0.004301  0.043281  -0.035225  -0.039625
# Past_Mental            -0.039941  0.086911  -0.080599  -0.017597
# K6                      0.111327 -0.210384   0.201008  -0.024629
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,cmap='seismic');

# %%
import numpy as np

# %%
mask1 = np.triu(np.ones_like(corr,dtype=bool))
mask2 = np.tril(np.ones_like(corr,dtype=bool))
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot = True, cmap = "seismic", mask = mask1);

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i,j])) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
print(len(corr_features))
print(corr_features)
# Out:
# 2
# {'Age_Group', 'PHQ9'}

# %%
X_train.head()
# Out:
#       Sex       Age  Age_Group  Job_Group  Health_Worker_Self  \
# 3200    0  0.211268   0.666667        0.0                   1
# 8397    0  0.154930   0.666667        0.0                   0
# 4000    0  0.492958   0.333333        0.0                   1
# 6928    1  0.183099   0.666667        0.0                   1
# 8510    0  0.323944   0.333333        0.0                   1
#
#       Health_Worker_Family  Married    Income  Current_Physical  \
# 3200                     1        1  0.333333                 1
# 8397                     0        0  0.000000                 1
# 4000                     1        1  0.222222                 1
# 6928                     1        0  0.222222                 1
# 8510                     1        1  0.222222                 1
#
#       Past_Physical  ...  Frustration  Covid_Sleepless  Difficulty_Living  \
# 3200              1  ...     0.166667         0.166667           0.166667
# ...

# %%
X_test.columns
# Out:
# Index(['Sex', 'Age', 'Age_Group', 'Job_Group', 'Health_Worker_Self',
#        'Health_Worker_Family', 'Married', 'Income', 'Current_Physical',
#        'Past_Physical', 'Current_Mental', 'Past_Mental', 'K6', 'PHQ9',
#        'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet', 'Healthy_Sleep',
#        'Activity', 'Interaction_Offline', 'Interaction_Online',
#        'Preventive_Behaviors', 'Optimism', 'Deterioration_Economy',
#        'Deterioration_Interact', 'Frustration', 'Covid_Sleepless',
#        'Difficulty_Living', 'Difficulty_Work', 'Residence_1', 'Residence_2',
#        'Residence_3', 'Residence_4', 'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
X_train.drop(['PHQ9', 'Age_Group'],axis='columns',inplace =  True)

# %%
X_train.columns
# Out:
# Index(['Sex', 'Age', 'Job_Group', 'Health_Worker_Self', 'Health_Worker_Family',
#        'Married', 'Income', 'Current_Physical', 'Past_Physical',
#        'Current_Mental', 'Past_Mental', 'K6', 'UCLA_LS3', 'LSNS6', 'Exercise',
#        'Healthy_Diet', 'Healthy_Sleep', 'Activity', 'Interaction_Offline',
#        'Interaction_Online', 'Preventive_Behaviors', 'Optimism',
#        'Deterioration_Economy', 'Deterioration_Interact', 'Frustration',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
X_test.drop(['PHQ9', 'Age_Group'],axis='columns',inplace=True)

# %%
X_test.columns
# Out:
# Index(['Sex', 'Age', 'Job_Group', 'Health_Worker_Self', 'Health_Worker_Family',
#        'Married', 'Income', 'Current_Physical', 'Past_Physical',
#        'Current_Mental', 'Past_Mental', 'K6', 'UCLA_LS3', 'LSNS6', 'Exercise',
#        'Healthy_Diet', 'Healthy_Sleep', 'Activity', 'Interaction_Offline',
#        'Interaction_Online', 'Preventive_Behaviors', 'Optimism',
#        'Deterioration_Economy', 'Deterioration_Interact', 'Frustration',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info = mutual_info_classif(X_train,y_train,random_state=1)

# %%
mutual_info
# Out:
# array([0.02828122, 0.01132896, 0.009885  , 0.00319989, 0.00509238,
#        0.        , 0.01758014, 0.00158474, 0.00444948, 0.00161818,
#        0.00141297, 0.11739899, 0.02340459, 0.01754341, 0.06348211,
#        0.06043504, 0.07708033, 0.05494928, 0.06348674, 0.06081673,
#        0.11093347, 0.05156729, 0.09132465, 0.11096857, 0.24233207,
#        0.24230611, 0.22017734, 0.17387013, 0.00136884, 0.00290966,
#        0.01653391, 0.00373438, 0.0111244 , 0.0163649 ])

# %%
len(mutual_info)
# Out:
# 34

# %%
X_train.shape
# Out:
# (7700, 34)

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# Frustration               0.242332
# Covid_Sleepless           0.242306
# Difficulty_Living         0.220177
# Difficulty_Work           0.173870
# K6                        0.117399
# Deterioration_Interact    0.110969
# Preventive_Behaviors      0.110933
# Deterioration_Economy     0.091325
# Healthy_Sleep             0.077080
# Interaction_Offline       0.063487
# Exercise                  0.063482
# Interaction_Online        0.060817
# Healthy_Diet              0.060435
# Activity                  0.054949
# Optimism                  0.051567
# Sex                       0.028281
# UCLA_LS3                  0.023405
# Income                    0.017580
# LSNS6                     0.017543
# Residence_3               0.016534
# Residence_6               0.016365
# Age                       0.011329
# Residence_5               0.011124
# Job_Group                 0.009885
# Health_Worker_Family      0.005092
# Past_Physical             0.004449
# Residence_4               0.003734
# ...

# %%
plt.figure(figsize = (20,8))
mutual_info.sort_values(ascending=False).plot.bar();

# %%
from sklearn.feature_selection import SelectKBest

# %%
sel_sqrt_cols=SelectKBest(mutual_info_classif,k=5)
sel_sqrt_cols.fit(X_train,y_train)
X_train.columns[sel_sqrt_cols.get_support()]
# Out:
# Index(['Preventive_Behaviors', 'Frustration', 'Covid_Sleepless',
#        'Difficulty_Living', 'Difficulty_Work'],
#       dtype='object')

# %%
mutual_info_selected_KBest = X_train.columns[sel_sqrt_cols.get_support()]
X_train.columns[sel_sqrt_cols.get_support()]
# Out:
# Index(['Preventive_Behaviors', 'Frustration', 'Covid_Sleepless',
#        'Difficulty_Living', 'Difficulty_Work'],
#       dtype='object')

# %%
from sklearn.feature_selection import SelectPercentile

# %%
sel_sqrt_cols=SelectKBest(mutual_info_classif,k=5)
sel_sqrt_cols.fit(X_train,y_train)
X_train.columns[sel_sqrt_cols.get_support()]
# Out:
# Index(['Preventive_Behaviors', 'Frustration', 'Covid_Sleepless',
#        'Difficulty_Living', 'Difficulty_Work'],
#       dtype='object')

# %%
mutual_info_selected_Percentile = X_train.columns[sel_sqrt_cols.get_support()]
X_train.columns[sel_sqrt_cols.get_support()]
# Out:
# Index(['Preventive_Behaviors', 'Frustration', 'Covid_Sleepless',
#        'Difficulty_Living', 'Difficulty_Work'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings('ignore')

rfc = RandomForestClassifier(random_state=1)
rfecv = RFECV(estimator=rfc, step=1, cv=StratifiedKFold(5), scoring='accuracy')
rfecv.fit(X_train, y_train)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(random_state=1), scoring='accuracy')

# %%
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 31

# %%
plt.figure(figsize=(16, 9))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_, color='#303F9F', linewidth=3)
plt.show()

# %%
print(np.where(rfecv.support_ == False)[0])
# Out:
# [3 7 9]

# %%
selected_features = X_train.drop(X_train.columns[np.where(rfecv.support_ == False)[0]], axis=1)

# %%
rfecv.estimator_.feature_importances_
# Out:
# array([0.01416604, 0.0627449 , 0.0190574 , 0.00701847, 0.01308394,
#        0.04067122, 0.00613989, 0.00839846, 0.06040098, 0.05475101,
#        0.05530342, 0.03748335, 0.03598556, 0.03871006, 0.03687779,
#        0.03684988, 0.03447385, 0.04583465, 0.03620177, 0.03961498,
#        0.03119028, 0.06321618, 0.05899348, 0.05923277, 0.04500293,
#        0.0120302 , 0.0108199 , 0.00936064, 0.00833628, 0.01024237,
#        0.00780736])

# %%
dset = pd.DataFrame()
dset['attr'] = selected_features.columns
dset['importance'] = rfecv.estimator_.feature_importances_
dset = dset.sort_values(by='importance', ascending=False)

plt.figure(figsize=(16, 10))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %%
dset
# Out:
#                       attr  importance
# 21             Frustration    0.063216
# 1                      Age    0.062745
# 8                       K6    0.060401
# 23       Difficulty_Living    0.059233
# 22         Covid_Sleepless    0.058993
# 10                   LSNS6    0.055303
# 9                 UCLA_LS3    0.054751
# 17    Preventive_Behaviors    0.045835
# 24         Difficulty_Work    0.045003
# 5                   Income    0.040671
# 19   Deterioration_Economy    0.039615
# 13           Healthy_Sleep    0.038710
# 11                Exercise    0.037483
# 14                Activity    0.036878
# 15     Interaction_Offline    0.036850
# 18                Optimism    0.036202
# 12            Healthy_Diet    0.035986
# 16      Interaction_Online    0.034474
# 20  Deterioration_Interact    0.031190
# 2                Job_Group    0.019057
# 0                      Sex    0.014166
# 4                  Married    0.013084
# 25             Residence_1    0.012030
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start=100,stop=2000,num=5)]
max_features = ['auto','sqrt','log2']
max_depth = [int(x) for x in np.linspace(5,1000,10)]
min_samples_split = [2,5,10,14]
min_samples_leaf = [1,2,6,4,8]
random_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
    'criterion': ['entropy','gini']
}
print(random_grid)
# Out:
# {'n_estimators': [100, 575, 1050, 1525, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [5, 115, 226, 336, 447, 557, 668, 778, 889, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 6, 4, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=RandomForestClassifier()

# %%
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=200,cv=3,verbose=2,
                               random_state=1,n_jobs=-1)

# %%
rf_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [5, 115, 226, 336, 447,
#                                                       557, 668, 778, 889,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 6, 4, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [100, 575, 1050, 1525,
#                                                          2000]},
#                    random_state=1, verbose=2)

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 1050,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 668,
#  'criterion': 'entropy'}

# %%
rf_randomcv
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [5, 115, 226, 336, 447,
#                                                       557, 668, 778, 889,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 6, 4, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [100, 575, 1050, 1525,
#                                                          2000]},
#                    random_state=1, verbose=2)

# %%
rf_randomcv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=668, min_samples_leaf=2,
#                        n_estimators=1050)

# %%
from sklearn.ensemble import RandomForestClassifier as rfc 
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix

rfc = rfc(n_estimators = 1050,
 min_samples_split = 2,
 min_samples_leaf = 2,
 max_features = 'sqrt',
 max_depth = 668,
 criterion = 'entropy') 
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
print(accuracy_score(y_train, rfc.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9857142857142858
# 0.5

# %%
from sklearn.neighbors import KNeighborsClassifier as knc

n_neighbors = [int(x) for x in np.linspace(start=5,stop=200,num=5)]
p = [1,2]
random_grid = {
    'n_neighbors': n_estimators,
    'p': p
}

# %%
print(random_grid)
# Out:
# {'n_neighbors': [100, 575, 1050, 1525, 2000], 'p': [1, 2]}

# %%
kn = knc()

# %%
kn_randomcv = RandomizedSearchCV(estimator=kn,param_distributions=random_grid,n_iter=200,cv=3,verbose=2,
                               random_state=1,n_jobs=-1)

# %%
kn_randomcv.fit(X_train,y_train)
#kn_randomcv
#kn_randomcv.best_estimator_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=KNeighborsClassifier(), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'n_neighbors': [100, 575, 1050, 1525,
#                                                         2000],
#                                         'p': [1, 2]},
#                    random_state=1, verbose=2)

# %%
kn_randomcv.best_params_
# Out:
# {'p': 1, 'n_neighbors': 100}

# %%
kn = knc(n_neighbors=100, p=1)
kn.fit(X_train, y_train)
y_pred = kn.predict(X_test)
print(accuracy_score(y_train, kn.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.44441558441558443
# 0.4418483904465213

# %%
from sklearn.tree import DecisionTreeClassifier as dtc

max_features = ['auto','sqrt','log2']
max_depth = [int(x) for x in np.linspace(5,1000,10)]
min_samples_split = [2,5,10,14]
min_samples_leaf = [1,2,6,4,8]
criterion = ['entropy','gini']
random_grid = {
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
    'criterion': ['entropy','gini']
}
print(random_grid)
# Out:
# {'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [5, 115, 226, 336, 447, 557, 668, 778, 889, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 6, 4, 8], 'criterion': ['entropy', 'gini']}

# %%
dt = dtc()
dt_randomcv = RandomizedSearchCV(estimator=dt,param_distributions=random_grid,n_iter=200,cv=3,verbose=2,
                               random_state=1,n_jobs=-1)
dt_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [5, 115, 226, 336, 447,
#                                                       557, 668, 778, 889,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 6, 4, 8],
#                                         'min_samples_split': [2, 5, 10, 14]},
#                    random_state=1, verbose=2)

# %%
dt_randomcv.best_params_
# Out:
# {'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 5,
#  'criterion': 'entropy'}

# %%
dt = dtc(min_samples_split = 5,
 min_samples_leaf = 1,
 max_features = 'log2',
 max_depth = 5,
 criterion = 'entropy')
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
print(accuracy_score(y_train, dt.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.43948051948051947
# 0.43769470404984423

# %%
from sklearn.svm import SVC as svc

C = [int(x) for x in np.linspace(start=5,stop=200,num=5)]
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
degree = [1,2,3]
random_grid = {
    'C': C,
    'kernel': kernel,
    'degree': degree
}
print(random_grid)
# Out:
# {'C': [5, 53, 102, 151, 200], 'kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'degree': [1, 2, 3]}

# %%
sv =svc()
sv_randomcv = RandomizedSearchCV(estimator=sv,param_distributions=random_grid,n_iter=200,cv=3,verbose=2,
                               random_state=1,n_jobs=-1)
sv_randomcv.fit(X_train,y_train)
#sv_randomcv.best_params_
#sv_randomcv
#sv_randomcv.best_estimator_
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# RandomizedSearchCV(cv=3, estimator=SVC(), n_iter=200, n_jobs=-1,
#                    param_distributions={'C': [5, 53, 102, 151, 200],
#                                         'degree': [1, 2, 3],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']},
#                    random_state=1, verbose=2)

# %%
sv_randomcv.best_params_
# Out:
# {'kernel': 'poly', 'degree': 1, 'C': 53}

# %%
sv = svc(kernel = 'poly', degree = 1, C = 53)
sv.fit(X_train, y_train)
y_pred = sv.predict(X_test)
print(accuracy_score(y_train, sv.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.4620779220779221
# 0.45119418483904467

# %%
from sklearn.linear_model import LogisticRegression as lrc

C = [int(x) for x in np.linspace(start=5,stop=200,num=5)]
penalty = ['l1', 'l2', 'elasticnet']
random_grid = {
    'C': C,
    'penalty' : penalty
}
print(random_grid)
# Out:
# {'C': [5, 53, 102, 151, 200], 'penalty': ['l1', 'l2', 'elasticnet']}

# %%
lr =lrc()
lr_randomcv = RandomizedSearchCV(estimator=lr,param_distributions=random_grid,n_iter=200,cv=3,verbose=2,
                               random_state=1,n_jobs=-1)
lr_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# RandomizedSearchCV(cv=3, estimator=LogisticRegression(), n_iter=200, n_jobs=-1,
#                    param_distributions={'C': [5, 53, 102, 151, 200],
#                                         'penalty': ['l1', 'l2', 'elasticnet']},
#                    random_state=1, verbose=2)

# %%
lr_randomcv.best_params_
# Out:
# {'penalty': 'l2', 'C': 5}

# %%
lr = lrc(penalty = 'l2', C = 5)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_train, lr.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.4523376623376623
# 0.4485981308411215

# %%
import lime
from lime import lime_tabular

explainer = lime_tabular.LimeTabularExplainer(
    training_data=np.array(X_train),
    feature_names=X_train.columns,
    class_names=['1','2','3','4','5','6','7'], # Check your class names in the CSV file. It should be 1, 2, 3, 4, 5 I think
    mode='classification'
)

exp = explainer.explain_instance(
    data_row=X_test.iloc[0],
    predict_fn=rfc.predict_proba
)

exp.show_in_notebook(show_table=True)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# ...

# %%
df.Covid_Anxiety.value_counts()
# Out:
# 5    3023
# 4    2011
# 1    1294
# 6     959
# 3     914
# 2     890
# 7     535
# Name: Covid_Anxiety, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X[['Preventive_Behaviors', 'Frustration', 'Covid_Sleepless',
       'Difficulty_Living', 'Difficulty_Work']], y, test_size = 0.2, random_state = 1, stratify = y)

# %%
rf = RandomForestClassifier(n_estimators = 1050,
 min_samples_split = 2,
 min_samples_leaf = 2,
 max_depth = 668,
 criterion = 'entropy') 
rf.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6553246753246753
# 0.44963655244029077

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=rf.classes_)
disp.plot()

plt.show()

# %%
kn = knc(n_neighbors=100, p=1)
kn.fit(X_train, y_train)
y_pred = kn.predict(X_test)
print(accuracy_score(y_train, kn.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.49
# 0.4932502596053998

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=kn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=kn.classes_)
disp.plot()

plt.show()

# %%
dt = dtc(min_samples_split = 5,
 min_samples_leaf = 1,
 max_features = 'log2',
 max_depth = 5,
 criterion = 'entropy')
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
print(accuracy_score(y_train, dt.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.4705194805194805
# 0.4719626168224299

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=dt.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=dt.classes_)
disp.plot()

plt.show()

# %%
sv = svc(kernel = 'poly', degree = 1, C = 53)
sv.fit(X_train, y_train)
y_pred = sv.predict(X_test)
print(accuracy_score(y_train, sv.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.44181818181818183
# 0.4402907580477674

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=sv.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=sv.classes_)
disp.plot()

plt.show()

# %%
lr = lrc(penalty = 'l2', C = 5)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_train, lr.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.4442857142857143
# 0.4434060228452752

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=sv.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=sv.classes_)
disp.plot()

plt.show()

# %%
df.columns
# Out:
# Index(['Sex', 'Age', 'Age_Group', 'Job_Group', 'Health_Worker_Self',
#        'Health_Worker_Family', 'Married', 'Income', 'Current_Physical',
#        'Past_Physical', 'Current_Mental', 'Past_Mental', 'K6', 'PHQ9',
#        'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet', 'Healthy_Sleep',
#        'Activity', 'Interaction_Offline', 'Interaction_Online',
#        'Preventive_Behaviors', 'Optimism', 'Deterioration_Economy',
#        'Deterioration_Interact', 'Frustration', 'Covid_Anxiety',
#        'Covid_Sleepless', 'Difficulty_Living', 'Difficulty_Work',
#        'Residence_1', 'Residence_2', 'Residence_3', 'Residence_4',
#        'Residence_5', 'Residence_6'],
#       dtype='object')

# %%
df.shape
# Out:
# (9626, 37)

# %%
from collections import Counter

# %%
print(Counter(df['Covid_Anxiety']).items())
# Out:
# dict_items([(5, 3023), (4, 2011), (1, 1294), (3, 914), (2, 890), (6, 959), (7, 535)])

# %%
Anxiety_1 = df[df['Covid_Anxiety']==1]

# %%
Anxiety_2 = df[df['Covid_Anxiety']==2]
Anxiety_3 = df[df['Covid_Anxiety']==3]
Anxiety_4 = df[df['Covid_Anxiety']==4]
Anxiety_5 = df[df['Covid_Anxiety']==5]
Anxiety_6 = df[df['Covid_Anxiety']==6]
Anxiety_7 = df[df['Covid_Anxiety']==7]

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=1)

# %%
X, y = rus.fit_resample(X,y)
#X.shape

# %%
#print(sorted(Counter(y.items())),y.shape)
y.value_counts()
# Out:
# 1    535
# 2    535
# 3    535
# 4    535
# 5    535
# 6    535
# 7    535
# Name: Covid_Anxiety, dtype: int64

# %%
dset['imp'] = rfecv.estimator_.feature_importances_>0.01
dset
# Out:
#                       attr  importance    imp
# 21             Frustration    0.063216   True
# 1                      Age    0.062745   True
# 8                       K6    0.060401   True
# 23       Difficulty_Living    0.059233  False
# 22         Covid_Sleepless    0.058993   True
# 10                   LSNS6    0.055303   True
# 9                 UCLA_LS3    0.054751  False
# 17    Preventive_Behaviors    0.045835  False
# 24         Difficulty_Work    0.045003   True
# 5                   Income    0.040671   True
# 19   Deterioration_Economy    0.039615   True
# 13           Healthy_Sleep    0.038710   True
# 11                Exercise    0.037483   True
# 14                Activity    0.036878   True
# 15     Interaction_Offline    0.036850   True
# 18                Optimism    0.036202   True
# 12            Healthy_Diet    0.035986   True
# 16      Interaction_Online    0.034474   True
# 20  Deterioration_Interact    0.031190   True
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X[['Frustration','Age','K6','Difficulty_Living','Covid_Sleepless','LSNS6','UCLA_LS3','Preventive_Behaviors','Difficulty_Work','Income','Deterioration_Economy','Healthy_Sleep','Exercise','Activity','Interaction_Offline','Deterioration_Interact','Job_Group','Sex','Married','Residence_1','Residence_2','Residence_3','Residence_4','Residence_5','Residence_6','Health_Worker_Family','Past_Physical','PHQ9','Age_Group']], y, test_size = 0.2, random_state = 1, stratify = y)
#'Frustration','Age','K6','Difficulty_Living','Covid_Sleepless','LSNS6','UCLA_LS3','Preventive_Behaviors','Difficulty_Work','Income','Deterioration_Economy','Healthy_Sleep','Exercise','Activity'

# %%
rf = RandomForestClassifier(n_estimators = 1050,
 min_samples_split = 2,
 min_samples_leaf = 2,
 max_features = 'sqrt',
 max_depth = 668,
 criterion = 'entropy') 
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9883177570093458
# 0.4819759679572764

# %%
import pandas as pd

# %%
df = pd.read_excel('japan_data.xlsx')

# %%
y = df['Covid_Anxiety']
X = df.drop(columns = 'Covid_Anxiety')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X[['Preventive_Behaviors', 'Frustration', 'Covid_Sleepless',
       'Difficulty_Living', 'Difficulty_Work']], y, test_size = 0.2, random_state = 1, stratify = y)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
rf = RandomForestClassifier() 
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6760423560555924
# 0.42876047640052933

# %%
rf = KNeighborsClassifier() 
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5579086697551291
# 0.4186149095721218

# %%
rf = DecisionTreeClassifier() 
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6760423560555924
# 0.4137626819585355

# %%
rf = SVC() 
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.49084491506728434
# 0.47198941332157035

# %%
rf = LogisticRegression() 
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(accuracy_score(y_train, rf.predict(X_train)))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.4472755349658063
# 0.42479047198941333
# C:\Users\nsyfi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
